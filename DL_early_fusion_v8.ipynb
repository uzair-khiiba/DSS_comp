# %%
import json
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import f1_score, classification_report
from sklearn.preprocessing import StandardScaler
import pandas as pd

# ============================================================================
# 1. OPTIMIZED DATASET WITH NORMALIZATION
# ============================================================================
class EmbeddingDataset(Dataset):
    def __init__(self, data, scaler=None, is_test=False, fit_scaler=False):
        self.data = data
        self.is_test = is_test
        
        # Extract features
        features = []
        for record in data:
            feat = record['image_embedding'] + record['text_embedding']
            features.append(feat)
        
        features = np.array(features)
        
        # Normalize features
        if fit_scaler:
            self.scaler = StandardScaler()
            features = self.scaler.fit_transform(features)
        elif scaler is not None:
            self.scaler = scaler
            features = self.scaler.transform(features)
        else:
            self.scaler = None
        
        self.features = features
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        features = torch.FloatTensor(self.features[idx])
        
        if self.is_test:
            return features, self.data[idx]['id']
        else:
            label = torch.LongTensor([self.data[idx]['label']])[0]
            return features, label

# ============================================================================
# 2. IMPROVED MODEL ARCHITECTURE
# ============================================================================
class OptimizedEarlyFusionMLP(nn.Module):
    def __init__(self, input_dim=1024, hidden_dims=[512, 256, 128, 64], 
                 dropout_rate=0.4):
        super().__init__()
        
        layers = []
        prev_dim = input_dim
        
        for i, hidden_dim in enumerate(hidden_dims):
            layers.extend([
                nn.Linear(prev_dim, hidden_dim),
                nn.BatchNorm1d(hidden_dim),
                nn.ReLU(),
                nn.Dropout(dropout_rate if i < len(hidden_dims) - 1 else dropout_rate * 0.5)
            ])
            prev_dim = hidden_dim
        
        # Output layer
        layers.append(nn.Linear(prev_dim, 2))
        self.model = nn.Sequential(*layers)
        
        # Initialize weights
        self._init_weights()
    
    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm1d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
    
    def forward(self, x):
        return self.model(x)

# ============================================================================
# 3. TRAINING FUNCTION WITH OPTIMIZATIONS
# ============================================================================
def train_model(train_loader, val_loader, device, config):
    """
    Train model with various optimizations
    
    config: dict with hyperparameters
    """
    model = OptimizedEarlyFusionMLP(
        hidden_dims=config['hidden_dims'],
        dropout_rate=config['dropout_rate']
    ).to(device)
    
    # Loss function with class weights (if imbalanced)
    criterion = nn.CrossEntropyLoss()
    
    # Optimizer with weight decay (L2 regularization)
    optimizer = optim.AdamW(
        model.parameters(), 
        lr=config['learning_rate'],
        weight_decay=config['weight_decay']
    )
    
    # Learning rate scheduler
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, 
        mode='max',  # maximize F1
        factor=0.5, 
        patience=5,
        min_lr=1e-6
    )
    
    # Alternative: CosineAnnealingLR
    # scheduler = optim.lr_scheduler.CosineAnnealingLR(
    #     optimizer, T_max=config['num_epochs'], eta_min=1e-6
    # )
    
    best_f1 = 0
    patience_counter = 0
    train_losses = []
    val_f1_scores = []
    
    for epoch in range(config['num_epochs']):
        # Training phase
        model.train()
        train_loss = 0
        train_preds = []
        train_labels = []
        
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            
            # Gradient clipping to prevent exploding gradients
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            
            optimizer.step()
            
            train_loss += loss.item()
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            train_preds.extend(preds)
            train_labels.extend(labels.cpu().numpy())
        
        avg_train_loss = train_loss / len(train_loader)
        train_f1 = f1_score(train_labels, train_preds, average='macro')
        
        # Validation phase
        model.eval()
        val_preds = []
        val_labels = []
        val_loss = 0
        
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                
                preds = torch.argmax(outputs, dim=1).cpu().numpy()
                val_preds.extend(preds)
                val_labels.extend(labels.cpu().numpy())
        
        avg_val_loss = val_loss / len(val_loader)
        val_f1 = f1_score(val_labels, val_preds, average='macro')
        
        train_losses.append(avg_train_loss)
        val_f1_scores.append(val_f1)
        
        # Get current learning rate before scheduler step
        current_lr = optimizer.param_groups[0]['lr']
        
        # Update learning rate
        old_lr = current_lr
        scheduler.step(val_f1)
        new_lr = optimizer.param_groups[0]['lr']
        
        # Print progress
        if (epoch + 1) % 5 == 0 or epoch == 0:
            print(f"Epoch {epoch+1}/{config['num_epochs']}")
            print(f"  Train Loss: {avg_train_loss:.4f}, Train F1: {train_f1:.4f}")
            print(f"  Val Loss: {avg_val_loss:.4f}, Val F1: {val_f1:.4f}")
            print(f"  LR: {new_lr:.6f}")
            if new_lr < old_lr:
                print(f"  → Learning rate reduced from {old_lr:.6f} to {new_lr:.6f}")
        
        # Save best model
        if val_f1 > best_f1:
            best_f1 = val_f1
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'best_f1': best_f1,
                'config': config
            }, 'best_model.pth')
            patience_counter = 0
            print(f"  ✓ New best F1: {best_f1:.4f}")
        else:
            patience_counter += 1
        
        # Early stopping
        if patience_counter >= config['early_stopping_patience']:
            print(f"\nEarly stopping triggered after {epoch+1} epochs")
            break
    
    print(f"\nTraining completed. Best Val F1: {best_f1:.4f}")
    
    # Print final classification report
    print("\nFinal Validation Classification Report:")
    print(classification_report(val_labels, val_preds, 
                                target_names=['Not Important', 'Important']))
    
    return model, best_f1, train_losses, val_f1_scores

# ============================================================================
# 4. HYPERPARAMETER SEARCH
# ============================================================================
def hyperparameter_search(train_data, device):
    """
    Optimized grid search focused on the best performing region
    """
    param_grid = [
        # ===== BASELINE: Current Best =====
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== DROPOUT FINE-TUNING (Exploring LOWER values) =====
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.50,  # Lower dropout
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.475,  # Even lower
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.45,  # Test lower bound
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.55,  # Keep for comparison
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== ARCHITECTURE VARIATIONS (With optimal dropout=0.525) =====
        # Deeper with same pattern
        {
            'hidden_dims': [768, 384, 192, 96],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Even deeper
        {
            'hidden_dims': [768, 384, 192, 96, 48],
            'dropout_rate': 0.50,  # Lower for deeper network
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Slightly wider first layer
        {
            'hidden_dims': [832, 416, 208],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # More gradual reduction
        {
            'hidden_dims': [768, 512, 256, 128],
            'dropout_rate': 0.50,  # Lower for deeper network
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== LEARNING RATE FINE-TUNING =====
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.0008,  # Slightly lower
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.0012,  # Slightly higher
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.0015,  # Test higher LR with lower dropout
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== WEIGHT DECAY VARIATIONS =====
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 2e-5,  # More regularization
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 5e-6,  # Less regularization (lower dropout already helps)
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.50,  # Very low dropout
            'learning_rate': 0.001,
            'weight_decay': 2e-5,  # Compensate with more weight decay
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== BATCH SIZE VARIATIONS =====
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 64,  # Larger batch
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 16,  # Smaller batch (more gradient updates)
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.50,
            'learning_rate': 0.0012,  # Higher LR with larger batch
            'weight_decay': 1e-5,
            'batch_size': 64,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== COMBINED OPTIMIZATIONS =====
        # Lower dropout + lower LR (stable training)
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.475,
            'learning_rate': 0.0008,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Lower dropout + higher LR (faster convergence)
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.50,
            'learning_rate': 0.0012,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Deeper + low dropout + more regularization
        {
            'hidden_dims': [768, 384, 192, 96],
            'dropout_rate': 0.475,
            'learning_rate': 0.001,
            'weight_decay': 2e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Wider + optimal dropout
        {
            'hidden_dims': [896, 448, 224],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Best config with smaller batch + higher LR
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.0015,
            'weight_decay': 1e-5,
            'batch_size': 16,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== ALTERNATIVE ARCHITECTURES =====
        # Very wide shallow network
        {
            'hidden_dims': [960, 480, 240],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Moderate depth with optimal dropout
        {
            'hidden_dims': [768, 576, 384, 192],
            'dropout_rate': 0.50,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Symmetric reduction pattern
        {
            'hidden_dims': [704, 384, 192, 96],
            'dropout_rate': 0.50,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Best config with extended training
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 150,  # More epochs
            'early_stopping_patience': 25
        },
    ]
    
    best_config = None
    best_score = 0
    results_log = []
    
    for i, config in enumerate(param_grid):
        print(f"\n{'='*60}")
        print(f"Testing configuration {i+1}/{len(param_grid)}")
        print(f"{'='*60}")
        print(config)
        
        # Split data
        train_split, val_split = train_test_split(
            train_data, test_size=0.2, random_state=42, 
            stratify=[d['label'] for d in train_data]
        )
        
        # Create datasets
        train_dataset = EmbeddingDataset(train_split, fit_scaler=True)
        val_dataset = EmbeddingDataset(val_split, scaler=train_dataset.scaler)
        
        train_loader = DataLoader(
            train_dataset, 
            batch_size=config['batch_size'], 
            shuffle=True
        )
        val_loader = DataLoader(
            val_dataset, 
            batch_size=config['batch_size'], 
            shuffle=False
        )
        
        # Train model
        _, f1, _, _ = train_model(train_loader, val_loader, device, config)
        
        # Log results
        results_log.append({
            'config_idx': i + 1,
            'f1_score': f1,
            'config': config
        })
        
        if f1 > best_score:
            best_score = f1
            best_config = config
            print(f"\n✓ New best configuration! F1: {f1:.4f}")
    
    # Print summary of all results
    print(f"\n{'='*60}")
    print("SUMMARY OF ALL CONFIGURATIONS:")
    print(f"{'='*60}")
    results_log.sort(key=lambda x: x['f1_score'], reverse=True)
    for i, result in enumerate(results_log[:5]):  # Top 5
        print(f"\n{i+1}. F1: {result['f1_score']:.4f}")
        print(f"   Config {result['config_idx']}: {result['config']}")
    
    print(f"\n{'='*60}")
    print("BEST CONFIGURATION:")
    print(best_config)
    print(f"Best F1 Score: {best_score:.4f}")
    print(f"{'='*60}")
    
    return best_config
# ============================================================================
# 5. CROSS-VALIDATION FOR ROBUST EVALUATION
# ============================================================================
def cross_validate_model(data, device, config, n_folds=5):
    """
    K-fold cross-validation for more robust performance estimate
    """
    labels = [d['label'] for d in data]
    skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=42)
    
    fold_scores = []
    
    for fold, (train_idx, val_idx) in enumerate(skf.split(data, labels)):
        print(f"\n{'='*60}")
        print(f"Fold {fold + 1}/{n_folds}")
        print(f"{'='*60}")
        
        train_data = [data[i] for i in train_idx]
        val_data = [data[i] for i in val_idx]
        
        # Create datasets
        train_dataset = EmbeddingDataset(train_data, fit_scaler=True)
        val_dataset = EmbeddingDataset(val_data, scaler=train_dataset.scaler)
        
        train_loader = DataLoader(
            train_dataset, 
            batch_size=config['batch_size'], 
            shuffle=True
        )
        val_loader = DataLoader(
            val_dataset, 
            batch_size=config['batch_size'], 
            shuffle=False
        )
        
        # Train model
        _, f1, _, _ = train_model(train_loader, val_loader, device, config)
        fold_scores.append(f1)
    
    print(f"\n{'='*60}")
    print("Cross-Validation Results:")
    print(f"Fold Scores: {[f'{s:.4f}' for s in fold_scores]}")
    print(f"Mean F1: {np.mean(fold_scores):.4f} ± {np.std(fold_scores):.4f}")
    print(f"{'='*60}")
    
    return fold_scores

# ============================================================================
# 6. MAIN TRAINING PIPELINE
# ============================================================================
def main():
    # Set random seeds for reproducibility
    torch.manual_seed(42)
    np.random.seed(42)
    
    # Device setup
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")
    
    # Load data
    print("\nLoading training data...")
    with open('train_part1.json', 'r') as f:
        data = json.load(f)
    
    print(f"Total samples: {len(data)}")
    labels = [d['label'] for d in data]
    print(f"Class distribution: 0={labels.count(0)}, 1={labels.count(1)}")
    
    # Option 2: Hyperparameter search (uncomment to use)
    best_config = hyperparameter_search(data, device)
    
    # Option 3: Cross-validation (uncomment to use)
    #cv_scores = cross_validate_model(data, device, best_config, n_folds=5)
    
    # Final training on full data with train/val split
    print("\nTraining final model...")
    train_data, val_data = train_test_split(
        data, test_size=0.2, random_state=42,
        stratify=[d['label'] for d in data]
    )
    
    train_dataset = EmbeddingDataset(train_data, fit_scaler=True)
    val_dataset = EmbeddingDataset(val_data, scaler=train_dataset.scaler)
    
    train_loader = DataLoader(
        train_dataset, 
        batch_size=best_config['batch_size'], 
        shuffle=True
    )
    val_loader = DataLoader(
        val_dataset, 
        batch_size=best_config['batch_size'], 
        shuffle=False
    )
    
    model, best_f1, train_losses, val_f1s = train_model(
        train_loader, val_loader, device, best_config
    )
    
    # Load best model for prediction
    checkpoint = torch.load('best_model.pth')
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()
    
    # Make predictions on test set
    print("\nMaking predictions on test set...")
    with open('test.json', 'r') as f:
        test_data = json.load(f)
    
    test_dataset = EmbeddingDataset(
        test_data, 
        scaler=train_dataset.scaler, 
        is_test=True
    )
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
    
    predictions = []
    test_ids = []
    
    with torch.no_grad():
        for features, ids in test_loader:
            features = features.to(device)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            predictions.extend(preds)
            # Convert tensor IDs to regular integers/numbers
            if isinstance(ids, torch.Tensor):
                test_ids.extend(ids.cpu().numpy().tolist())
            else:
                test_ids.extend(ids)
    
    # Create submission
    submission = pd.DataFrame({
        'row_id': test_ids,
        'target': predictions
    })
    submission.to_csv('ann_v8.csv', index=False)
    print("\n✓ Submission file created: submission.csv")
    print(f"Predictions: 0={predictions.count(0)}, 1={predictions.count(1)}")

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
#
# Loading training data...
# Total samples: 1530
# Class distribution: 0=1326, 1=204
#
# ============================================================
# Testing configuration 1/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 2.7958, Train F1: 0.5086
#   Val Loss: 0.7702, Val F1: 0.6685
#   LR: 0.001000
#   ✓ New best F1: 0.6685
#   ✓ New best F1: 0.7052
#   ✓ New best F1: 0.7268
# Epoch 5/120
#   Train Loss: 1.3148, Train F1: 0.6778
#   Val Loss: 0.9164, Val F1: 0.7061
#   LR: 0.001000
# Epoch 10/120
#   Train Loss: 0.6983, Train F1: 0.7890
#   Val Loss: 1.0411, Val F1: 0.7009
#   LR: 0.000500
# Epoch 15/120
#   Train Loss: 0.5787, Train F1: 0.8109
#   Val Loss: 1.2515, Val F1: 0.6264
#   LR: 0.000250
#   → Learning rate reduced from 0.000500 to 0.000250
# Epoch 20/120
#   Train Loss: 0.3089, Train F1: 0.8708
#   Val Loss: 1.1431, Val F1: 0.7079
#   LR: 0.000250
#
# Early stopping triggered after 23 epochs
#
# Training completed. Best Val F1: 0.7268
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.92      0.94      0.93       265
#     Important       0.56      0.49      0.52        41
#
#      accuracy                           0.88       306
#     macro avg       0.74      0.71      0.73       306
#  weighted avg       0.87      0.88      0.88       306
#
#
# ✓ New best configuration! F1: 0.7268
#
# ============================================================
# Testing configuration 2/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 5.9196, Train F1: 0.4004
#   Val Loss: 1.4346, Val F1: 0.6043
#   LR: 0.001000
#   ✓ New best F1: 0.6043
#   ✓ New best F1: 0.6574
#   ✓ New best F1: 0.6943
#   ✓ New best F1: 0.7067
# Epoch 5/120
#   Train Loss: 1.3794, Train F1: 0.6549
#   Val Loss: 0.9206, Val F1: 0.7063
#   LR: 0.001000
# Epoch 10/120
#   Train Loss: 0.8736, Train F1: 0.7711
#   Val Loss: 1.1211, Val F1: 0.6947
#   LR: 0.000500
#   → Learning rate reduced from 0.001000 to 0.000500
# Epoch 15/120
#   Train Loss: 0.4721, Train F1: 0.8424
#   Val Loss: 1.2305, Val F1: 0.6500
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.1915, Train F1: 0.9073
#   Val Loss: 1.1899, Val F1: 0.6914
#   LR: 0.000250
#
# Early stopping triggered after 24 epochs
#
# Training completed. Best Val F1: 0.7067
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.89      0.94      0.91       265
#     Important       0.39      0.27      0.32        41
#
#      accuracy                           0.85       306
#     macro avg       0.64      0.60      0.62       306
#  weighted avg       0.83      0.85      0.83       306
#
#
# ============================================================
# Testing configuration 3/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.475, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 4.2929, Train F1: 0.5012
#   Val Loss: 1.0013, Val F1: 0.6112
#   LR: 0.001000
#   ✓ New best F1: 0.6112
#   ✓ New best F1: 0.6397
#   ✓ New best F1: 0.6510
#   ✓ New best F1: 0.6656
# Epoch 5/120
#   Train Loss: 1.3841, Train F1: 0.6759
#   Val Loss: 1.1812, Val F1: 0.6902
#   LR: 0.001000
#   ✓ New best F1: 0.6902
# Epoch 10/120
#   Train Loss: 0.7327, Train F1: 0.7878
#   Val Loss: 1.6577, Val F1: 0.6085
#   LR: 0.001000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 716
#     713     print(f"Predictions: 0={predictions.count(0)}, 1={predictions.count(1)}")
#     715 if __name__ == "__main__":
# --> 716     main()
#
# Cell In[1], line 644, in main()
#     641 print(f"Class distribution: 0={labels.count(0)}, 1={labels.count(1)}")
#     643 # Option 2: Hyperparameter search (uncomment to use)
# --> 644 best_config = hyperparameter_search(data, device)
#     646 # Option 3: Cross-validation (uncomment to use)
#     647 #cv_scores = cross_validate_model(data, device, best_config, n_folds=5)
#     648
#     649 # Final training on full data with train/val split
#     650 print("\nTraining final model...")
#
# Cell In[1], line 545, in hyperparameter_search(train_data, device)
#     538 val_loader = DataLoader(
#     539     val_dataset,
#     540     batch_size=config['batch_size'],
#     541     shuffle=False
#     542 )
#     544 # Train model
# --> 545 _, f1, _, _ = train_model(train_loader, val_loader, device, config)
#     547 # Log results
#     548 results_log.append({
#     549     'config_idx': i + 1,
#     550     'f1_score': f1,
#     551     'config': config
#     552 })
#
# Cell In[1], line 170, in train_model(train_loader, val_loader, device, config)
#     167 val_loss = 0
#     169 with torch.no_grad():
# --> 170     for features, labels in val_loader:
#     171         features, labels = features.to(device), labels.to(device)
#     172         outputs = model(features)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:701, in _BaseDataLoaderIter.__next__(self)
#     698 if self._sampler_iter is None:
#     699     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700     self._reset()  # type: ignore[call-arg]
# --> 701 data = self._next_data()
#     702 self._num_yielded += 1
#     703 if (
#     704     self._dataset_kind == _DatasetKind.Iterable
#     705     and self._IterableDataset_len_called is not None
#     706     and self._num_yielded > self._IterableDataset_len_called
#     707 ):
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\dataloader.py:757, in _SingleProcessDataLoaderIter._next_data(self)
#     755 def _next_data(self):
#     756     index = self._next_index()  # may raise StopIteration
# --> 757     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758     if self._pin_memory:
#     759         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[1], line 44, in EmbeddingDataset.__getitem__(self, idx)
#      43 def __getitem__(self, idx):
# ---> 44     features = torch.FloatTensor(self.features[idx])
#      46     if self.is_test:
#      47         return features, self.data[idx]['id']
#
# KeyboardInterrupt:

# %%
import json
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import f1_score, classification_report
from sklearn.preprocessing import StandardScaler
import pandas as pd

# ============================================================================
# 1. OPTIMIZED DATASET WITH NORMALIZATION
# ============================================================================
class EmbeddingDataset(Dataset):
    def __init__(self, data, scaler=None, is_test=False, fit_scaler=False):
        self.data = data
        self.is_test = is_test
        
        # Extract features
        features = []
        for record in data:
            feat = record['image_embedding'] + record['text_embedding']
            features.append(feat)
        
        features = np.array(features)
        
        # Normalize features
        if fit_scaler:
            self.scaler = StandardScaler()
            features = self.scaler.fit_transform(features)
        elif scaler is not None:
            self.scaler = scaler
            features = self.scaler.transform(features)
        else:
            self.scaler = None
        
        self.features = features
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        features = torch.FloatTensor(self.features[idx])
        
        if self.is_test:
            return features, self.data[idx]['id']
        else:
            label = torch.LongTensor([self.data[idx]['label']])[0]
            return features, label

# ============================================================================
# 2. IMPROVED MODEL ARCHITECTURE
# ============================================================================
class OptimizedEarlyFusionMLP(nn.Module):
    def __init__(self, input_dim=1024, hidden_dims=[512, 256, 128, 64], 
                 dropout_rate=0.4):
        super().__init__()
        
        layers = []
        prev_dim = input_dim
        
        for i, hidden_dim in enumerate(hidden_dims):
            layers.extend([
                nn.Linear(prev_dim, hidden_dim),
                nn.BatchNorm1d(hidden_dim),
                nn.ReLU(),
                nn.Dropout(dropout_rate if i < len(hidden_dims) - 1 else dropout_rate * 0.5)
            ])
            prev_dim = hidden_dim
        
        # Output layer
        layers.append(nn.Linear(prev_dim, 2))
        self.model = nn.Sequential(*layers)
        
        # Initialize weights
        self._init_weights()
    
    def _init_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Linear):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm1d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
    
    def forward(self, x):
        return self.model(x)

# ============================================================================
# 3. TRAINING FUNCTION WITH OPTIMIZATIONS
# ============================================================================
def train_model(train_loader, val_loader, device, config):
    """
    Train model with various optimizations
    
    config: dict with hyperparameters
    """
    model = OptimizedEarlyFusionMLP(
        hidden_dims=config['hidden_dims'],
        dropout_rate=config['dropout_rate']
    ).to(device)
    
    # Loss function with class weights (if imbalanced)
    criterion = nn.CrossEntropyLoss()
    
    # Optimizer with weight decay (L2 regularization)
    optimizer = optim.AdamW(
        model.parameters(), 
        lr=config['learning_rate'],
        weight_decay=config['weight_decay']
    )
    
    # Learning rate scheduler
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, 
        mode='max',  # maximize F1
        factor=0.5, 
        patience=5,
        min_lr=1e-6
    )
    
    # Alternative: CosineAnnealingLR
    # scheduler = optim.lr_scheduler.CosineAnnealingLR(
    #     optimizer, T_max=config['num_epochs'], eta_min=1e-6
    # )
    
    best_f1 = 0
    patience_counter = 0
    train_losses = []
    val_f1_scores = []
    
    for epoch in range(config['num_epochs']):
        # Training phase
        model.train()
        train_loss = 0
        train_preds = []
        train_labels = []
        
        for features, labels in train_loader:
            features, labels = features.to(device), labels.to(device)
            
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels)
            loss.backward()
            
            # Gradient clipping to prevent exploding gradients
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            
            optimizer.step()
            
            train_loss += loss.item()
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            train_preds.extend(preds)
            train_labels.extend(labels.cpu().numpy())
        
        avg_train_loss = train_loss / len(train_loader)
        train_f1 = f1_score(train_labels, train_preds, average='macro')
        
        # Validation phase
        model.eval()
        val_preds = []
        val_labels = []
        val_loss = 0
        
        with torch.no_grad():
            for features, labels in val_loader:
                features, labels = features.to(device), labels.to(device)
                outputs = model(features)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                
                preds = torch.argmax(outputs, dim=1).cpu().numpy()
                val_preds.extend(preds)
                val_labels.extend(labels.cpu().numpy())
        
        avg_val_loss = val_loss / len(val_loader)
        val_f1 = f1_score(val_labels, val_preds, average='macro')
        
        train_losses.append(avg_train_loss)
        val_f1_scores.append(val_f1)
        
        # Get current learning rate before scheduler step
        current_lr = optimizer.param_groups[0]['lr']
        
        # Update learning rate
        old_lr = current_lr
        scheduler.step(val_f1)
        new_lr = optimizer.param_groups[0]['lr']
        
        # Print progress
        if (epoch + 1) % 5 == 0 or epoch == 0:
            print(f"Epoch {epoch+1}/{config['num_epochs']}")
            print(f"  Train Loss: {avg_train_loss:.4f}, Train F1: {train_f1:.4f}")
            print(f"  Val Loss: {avg_val_loss:.4f}, Val F1: {val_f1:.4f}")
            print(f"  LR: {new_lr:.6f}")
            if new_lr < old_lr:
                print(f"  → Learning rate reduced from {old_lr:.6f} to {new_lr:.6f}")
        
        # Save best model
        if val_f1 > best_f1:
            best_f1 = val_f1
            torch.save({
                'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'best_f1': best_f1,
                'config': config
            }, 'best_model.pth')
            patience_counter = 0
            print(f"  ✓ New best F1: {best_f1:.4f}")
        else:
            patience_counter += 1
        
        # Early stopping
        if patience_counter >= config['early_stopping_patience']:
            print(f"\nEarly stopping triggered after {epoch+1} epochs")
            break
    
    print(f"\nTraining completed. Best Val F1: {best_f1:.4f}")
    
    # Print final classification report
    print("\nFinal Validation Classification Report:")
    print(classification_report(val_labels, val_preds, 
                                target_names=['Not Important', 'Important']))
    
    return model, best_f1, train_losses, val_f1_scores

# ============================================================================
# 4. HYPERPARAMETER SEARCH
# ============================================================================
def hyperparameter_search(train_data, device):
    """
    Optimized grid search focused on the best performing region
    """
    param_grid = [
        # ===== BASELINE: Current Best =====
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== DROPOUT FINE-TUNING (Exploring LOWER values) =====
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.50,  # Lower dropout
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.475,  # Even lower
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.45,  # Test lower bound
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.55,  # Keep for comparison
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== ARCHITECTURE VARIATIONS (With optimal dropout=0.525) =====
        # Deeper with same pattern
        {
            'hidden_dims': [768, 384, 192, 96],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Even deeper
        {
            'hidden_dims': [768, 384, 192, 96, 48],
            'dropout_rate': 0.50,  # Lower for deeper network
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Slightly wider first layer
        {
            'hidden_dims': [832, 416, 208],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # More gradual reduction
        {
            'hidden_dims': [768, 512, 256, 128],
            'dropout_rate': 0.50,  # Lower for deeper network
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== LEARNING RATE FINE-TUNING =====
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.0008,  # Slightly lower
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.0012,  # Slightly higher
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.0015,  # Test higher LR with lower dropout
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== WEIGHT DECAY VARIATIONS =====
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 2e-5,  # More regularization
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 5e-6,  # Less regularization (lower dropout already helps)
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.50,  # Very low dropout
            'learning_rate': 0.001,
            'weight_decay': 2e-5,  # Compensate with more weight decay
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== BATCH SIZE VARIATIONS =====
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 64,  # Larger batch
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 16,  # Smaller batch (more gradient updates)
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.50,
            'learning_rate': 0.0012,  # Higher LR with larger batch
            'weight_decay': 1e-5,
            'batch_size': 64,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== COMBINED OPTIMIZATIONS =====
        # Lower dropout + lower LR (stable training)
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.475,
            'learning_rate': 0.0008,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Lower dropout + higher LR (faster convergence)
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.50,
            'learning_rate': 0.0012,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Deeper + low dropout + more regularization
        {
            'hidden_dims': [768, 384, 192, 96],
            'dropout_rate': 0.475,
            'learning_rate': 0.001,
            'weight_decay': 2e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Wider + optimal dropout
        {
            'hidden_dims': [896, 448, 224],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Best config with smaller batch + higher LR
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.0015,
            'weight_decay': 1e-5,
            'batch_size': 16,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        
        # ===== ALTERNATIVE ARCHITECTURES =====
        # Very wide shallow network
        {
            'hidden_dims': [960, 480, 240],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Moderate depth with optimal dropout
        {
            'hidden_dims': [768, 576, 384, 192],
            'dropout_rate': 0.50,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Symmetric reduction pattern
        {
            'hidden_dims': [704, 384, 192, 96],
            'dropout_rate': 0.50,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 120,
            'early_stopping_patience': 20
        },
        # Best config with extended training
        {
            'hidden_dims': [768, 384, 192],
            'dropout_rate': 0.525,
            'learning_rate': 0.001,
            'weight_decay': 1e-5,
            'batch_size': 32,
            'num_epochs': 150,  # More epochs
            'early_stopping_patience': 25
        },
    ]
    
    best_config = None
    best_score = 0
    results_log = []
    
    for i, config in enumerate(param_grid):
        print(f"\n{'='*60}")
        print(f"Testing configuration {i+1}/{len(param_grid)}")
        print(f"{'='*60}")
        print(config)
        
        # Split data
        train_split, val_split = train_test_split(
            train_data, test_size=0.2, random_state=42, 
            stratify=[d['label'] for d in train_data]
        )
        
        # Create datasets
        train_dataset = EmbeddingDataset(train_split, fit_scaler=True)
        val_dataset = EmbeddingDataset(val_split, scaler=train_dataset.scaler)
        
        train_loader = DataLoader(
            train_dataset, 
            batch_size=config['batch_size'], 
            shuffle=True
        )
        val_loader = DataLoader(
            val_dataset, 
            batch_size=config['batch_size'], 
            shuffle=False
        )
        
        # Train model
        _, f1, _, _ = train_model(train_loader, val_loader, device, config)
        
        # Log results
        results_log.append({
            'config_idx': i + 1,
            'f1_score': f1,
            'config': config
        })
        
        if f1 > best_score:
            best_score = f1
            best_config = config
            print(f"\n✓ New best configuration! F1: {f1:.4f}")
    
    # Print summary of all results
    print(f"\n{'='*60}")
    print("SUMMARY OF ALL CONFIGURATIONS:")
    print(f"{'='*60}")
    results_log.sort(key=lambda x: x['f1_score'], reverse=True)
    for i, result in enumerate(results_log[:5]):  # Top 5
        print(f"\n{i+1}. F1: {result['f1_score']:.4f}")
        print(f"   Config {result['config_idx']}: {result['config']}")
    
    print(f"\n{'='*60}")
    print("BEST CONFIGURATION:")
    print(best_config)
    print(f"Best F1 Score: {best_score:.4f}")
    print(f"{'='*60}")
    
    return best_config
# ============================================================================
# 5. CROSS-VALIDATION FOR ROBUST EVALUATION
# ============================================================================
def cross_validate_model(data, device, config, n_folds=5):
    """
    K-fold cross-validation for more robust performance estimate
    """
    labels = [d['label'] for d in data]
    skf = StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=42)
    
    fold_scores = []
    
    for fold, (train_idx, val_idx) in enumerate(skf.split(data, labels)):
        print(f"\n{'='*60}")
        print(f"Fold {fold + 1}/{n_folds}")
        print(f"{'='*60}")
        
        train_data = [data[i] for i in train_idx]
        val_data = [data[i] for i in val_idx]
        
        # Create datasets
        train_dataset = EmbeddingDataset(train_data, fit_scaler=True)
        val_dataset = EmbeddingDataset(val_data, scaler=train_dataset.scaler)
        
        train_loader = DataLoader(
            train_dataset, 
            batch_size=config['batch_size'], 
            shuffle=True
        )
        val_loader = DataLoader(
            val_dataset, 
            batch_size=config['batch_size'], 
            shuffle=False
        )
        
        # Train model
        _, f1, _, _ = train_model(train_loader, val_loader, device, config)
        fold_scores.append(f1)
    
    print(f"\n{'='*60}")
    print("Cross-Validation Results:")
    print(f"Fold Scores: {[f'{s:.4f}' for s in fold_scores]}")
    print(f"Mean F1: {np.mean(fold_scores):.4f} ± {np.std(fold_scores):.4f}")
    print(f"{'='*60}")
    
    return fold_scores

# ============================================================================
# 6. MAIN TRAINING PIPELINE
# ============================================================================
def main():
    # Set random seeds for reproducibility
    torch.manual_seed(42)
    np.random.seed(42)
    
    # Device setup
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")
    
    # Load data
    print("\nLoading training data...")
    with open('train_part1.json', 'r') as f:
        data = json.load(f)
    
    print(f"Total samples: {len(data)}")
    labels = [d['label'] for d in data]
    print(f"Class distribution: 0={labels.count(0)}, 1={labels.count(1)}")
    
    # Option 2: Hyperparameter search (uncomment to use)
    best_config = hyperparameter_search(data, device)
    
    # Option 3: Cross-validation (uncomment to use)
    #cv_scores = cross_validate_model(data, device, best_config, n_folds=5)
    
    # Final training on full data with train/val split
    print("\nTraining final model...")
    train_data, val_data = train_test_split(
        data, test_size=0.2, random_state=42,
        stratify=[d['label'] for d in data]
    )
    
    train_dataset = EmbeddingDataset(train_data, fit_scaler=True)
    val_dataset = EmbeddingDataset(val_data, scaler=train_dataset.scaler)
    
    train_loader = DataLoader(
        train_dataset, 
        batch_size=best_config['batch_size'], 
        shuffle=True
    )
    val_loader = DataLoader(
        val_dataset, 
        batch_size=best_config['batch_size'], 
        shuffle=False
    )
    
    model, best_f1, train_losses, val_f1s = train_model(
        train_loader, val_loader, device, best_config
    )
    
    # Load best model for prediction
    checkpoint = torch.load('best_model.pth')
    model.load_state_dict(checkpoint['model_state_dict'])
    model.eval()
    
    # Make predictions on test set
    print("\nMaking predictions on test set...")
    with open('test.json', 'r') as f:
        test_data = json.load(f)
    
    test_dataset = EmbeddingDataset(
        test_data, 
        scaler=train_dataset.scaler, 
        is_test=True
    )
    test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)
    
    predictions = []
    test_ids = []
    
    with torch.no_grad():
        for features, ids in test_loader:
            features = features.to(device)
            outputs = model(features)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            predictions.extend(preds)
            # Convert tensor IDs to regular integers/numbers
            if isinstance(ids, torch.Tensor):
                test_ids.extend(ids.cpu().numpy().tolist())
            else:
                test_ids.extend(ids)
    
    # Create submission
    submission = pd.DataFrame({
        'row_id': test_ids,
        'target': predictions
    })
    submission.to_csv('ann_v8.csv', index=False)
    print("\n✓ Submission file created: submission.csv")
    print(f"Predictions: 0={predictions.count(0)}, 1={predictions.count(1)}")

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda
#
# Loading training data...
# Total samples: 1530
# Class distribution: 0=1326, 1=204
#
# ============================================================
# Testing configuration 1/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 2.7958, Train F1: 0.5086
#   Val Loss: 0.7702, Val F1: 0.6685
#   LR: 0.001000
#   ✓ New best F1: 0.6685
#   ✓ New best F1: 0.7052
#   ✓ New best F1: 0.7268
# Epoch 5/120
#   Train Loss: 1.3148, Train F1: 0.6778
#   Val Loss: 0.9164, Val F1: 0.7061
#   LR: 0.001000
# Epoch 10/120
#   Train Loss: 0.6983, Train F1: 0.7890
#   Val Loss: 1.0411, Val F1: 0.7009
#   LR: 0.000500
# Epoch 15/120
#   Train Loss: 0.5787, Train F1: 0.8109
#   Val Loss: 1.2515, Val F1: 0.6264
#   LR: 0.000250
#   → Learning rate reduced from 0.000500 to 0.000250
# Epoch 20/120
#   Train Loss: 0.3089, Train F1: 0.8708
#   Val Loss: 1.1431, Val F1: 0.7079
#   LR: 0.000250
#
# Early stopping triggered after 23 epochs
#
# Training completed. Best Val F1: 0.7268
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.92      0.94      0.93       265
#     Important       0.56      0.49      0.52        41
#
#      accuracy                           0.88       306
#     macro avg       0.74      0.71      0.73       306
#  weighted avg       0.87      0.88      0.88       306
#
#
# ✓ New best configuration! F1: 0.7268
#
# ============================================================
# Testing configuration 2/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 5.9196, Train F1: 0.4004
#   Val Loss: 1.4346, Val F1: 0.6043
#   LR: 0.001000
#   ✓ New best F1: 0.6043
#   ✓ New best F1: 0.6574
#   ✓ New best F1: 0.6943
#   ✓ New best F1: 0.7067
# Epoch 5/120
#   Train Loss: 1.3794, Train F1: 0.6549
#   Val Loss: 0.9206, Val F1: 0.7063
#   LR: 0.001000
# Epoch 10/120
#   Train Loss: 0.8736, Train F1: 0.7711
#   Val Loss: 1.1211, Val F1: 0.6947
#   LR: 0.000500
#   → Learning rate reduced from 0.001000 to 0.000500
# Epoch 15/120
#   Train Loss: 0.4721, Train F1: 0.8424
#   Val Loss: 1.2305, Val F1: 0.6500
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.1915, Train F1: 0.9073
#   Val Loss: 1.1899, Val F1: 0.6914
#   LR: 0.000250
#
# Early stopping triggered after 24 epochs
#
# Training completed. Best Val F1: 0.7067
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.89      0.94      0.91       265
#     Important       0.39      0.27      0.32        41
#
#      accuracy                           0.85       306
#     macro avg       0.64      0.60      0.62       306
#  weighted avg       0.83      0.85      0.83       306
#
#
# ============================================================
# Testing configuration 3/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.475, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 4.2929, Train F1: 0.5012
#   Val Loss: 1.0013, Val F1: 0.6112
#   LR: 0.001000
#   ✓ New best F1: 0.6112
#   ✓ New best F1: 0.6397
#   ✓ New best F1: 0.6510
#   ✓ New best F1: 0.6656
# Epoch 5/120
#   Train Loss: 1.3841, Train F1: 0.6759
#   Val Loss: 1.1812, Val F1: 0.6902
#   LR: 0.001000
#   ✓ New best F1: 0.6902
# Epoch 10/120
#   Train Loss: 0.7327, Train F1: 0.7878
#   Val Loss: 1.6577, Val F1: 0.6085
#   LR: 0.001000
# Epoch 15/120
#   Train Loss: 0.4233, Train F1: 0.8655
#   Val Loss: 1.4753, Val F1: 0.6311
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.2119, Train F1: 0.9124
#   Val Loss: 1.6211, Val F1: 0.6549
#   LR: 0.000250
# Epoch 25/120
#   Train Loss: 0.1758, Train F1: 0.9256
#   Val Loss: 1.6541, Val F1: 0.6360
#   LR: 0.000125
#
# Early stopping triggered after 25 epochs
#
# Training completed. Best Val F1: 0.6902
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.90      0.92      0.91       265
#     Important       0.39      0.34      0.36        41
#
#      accuracy                           0.84       306
#     macro avg       0.64      0.63      0.64       306
#  weighted avg       0.83      0.84      0.84       306
#
#
# ============================================================
# Testing configuration 4/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.45, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 2.7544, Train F1: 0.5224
#   Val Loss: 0.8018, Val F1: 0.6815
#   LR: 0.001000
#   ✓ New best F1: 0.6815
#   ✓ New best F1: 0.7314
# Epoch 5/120
#   Train Loss: 0.9283, Train F1: 0.7230
#   Val Loss: 0.7894, Val F1: 0.7346
#   LR: 0.001000
#   ✓ New best F1: 0.7346
# Epoch 10/120
#   Train Loss: 0.4772, Train F1: 0.8357
#   Val Loss: 1.2424, Val F1: 0.6717
#   LR: 0.001000
# Epoch 15/120
#   Train Loss: 0.2723, Train F1: 0.8932
#   Val Loss: 1.1508, Val F1: 0.6474
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.1475, Train F1: 0.9249
#   Val Loss: 1.4200, Val F1: 0.6394
#   LR: 0.000250
# Epoch 25/120
#   Train Loss: 0.1030, Train F1: 0.9428
#   Val Loss: 1.4195, Val F1: 0.6229
#   LR: 0.000125
#
# Early stopping triggered after 25 epochs
#
# Training completed. Best Val F1: 0.7346
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.90      0.90      0.90       265
#     Important       0.35      0.34      0.35        41
#
#      accuracy                           0.83       306
#     macro avg       0.62      0.62      0.62       306
#  weighted avg       0.83      0.83      0.83       306
#
#
# ✓ New best configuration! F1: 0.7346
#
# ============================================================
# Testing configuration 5/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.55, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 6.4988, Train F1: 0.3897
#   Val Loss: 0.6123, Val F1: 0.6643
#   LR: 0.001000
#   ✓ New best F1: 0.6643
#   ✓ New best F1: 0.6836
#   ✓ New best F1: 0.6926
# Epoch 5/120
#   Train Loss: 1.3607, Train F1: 0.6609
#   Val Loss: 0.7747, Val F1: 0.7555
#   LR: 0.001000
#   ✓ New best F1: 0.7555
# Epoch 10/120
#   Train Loss: 0.9631, Train F1: 0.7397
#   Val Loss: 0.9584, Val F1: 0.6603
#   LR: 0.001000
# Epoch 15/120
#   Train Loss: 0.5211, Train F1: 0.8233
#   Val Loss: 0.9761, Val F1: 0.7003
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.3942, Train F1: 0.8323
#   Val Loss: 1.0482, Val F1: 0.6694
#   LR: 0.000250
# Epoch 25/120
#   Train Loss: 0.2755, Train F1: 0.8719
#   Val Loss: 1.1669, Val F1: 0.6695
#   LR: 0.000125
#
# Early stopping triggered after 25 epochs
#
# Training completed. Best Val F1: 0.7555
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.91      0.93      0.92       265
#     Important       0.46      0.39      0.42        41
#
#      accuracy                           0.86       306
#     macro avg       0.68      0.66      0.67       306
#  weighted avg       0.85      0.86      0.85       306
#
#
# ✓ New best configuration! F1: 0.7555
#
# ============================================================
# Testing configuration 6/27
# ============================================================
# {'hidden_dims': [768, 384, 192, 96], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 2.0892, Train F1: 0.5292
#   Val Loss: 0.5737, Val F1: 0.6304
#   LR: 0.001000
#   ✓ New best F1: 0.6304
#   ✓ New best F1: 0.7067
#   ✓ New best F1: 0.7387
# Epoch 5/120
#   Train Loss: 1.2102, Train F1: 0.5909
#   Val Loss: 0.5038, Val F1: 0.6631
#   LR: 0.001000
# Epoch 10/120
#   Train Loss: 0.7331, Train F1: 0.6355
#   Val Loss: 0.5180, Val F1: 0.7096
#   LR: 0.000500
# Epoch 15/120
#   Train Loss: 0.5132, Train F1: 0.6974
#   Val Loss: 0.5632, Val F1: 0.6104
#   LR: 0.000250
#   → Learning rate reduced from 0.000500 to 0.000250
# Epoch 20/120
#   Train Loss: 0.3296, Train F1: 0.7629
#   Val Loss: 0.5528, Val F1: 0.6304
#   LR: 0.000250
#
# Early stopping triggered after 23 epochs
#
# Training completed. Best Val F1: 0.7387
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.89      0.99      0.93       265
#     Important       0.70      0.17      0.27        41
#
#      accuracy                           0.88       306
#     macro avg       0.79      0.58      0.60       306
#  weighted avg       0.86      0.88      0.85       306
#
#
# ============================================================
# Testing configuration 7/27
# ============================================================
# {'hidden_dims': [768, 384, 192, 96, 48], 'dropout_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 1.8674, Train F1: 0.4668
#   Val Loss: 0.4030, Val F1: 0.5872
#   LR: 0.001000
#   ✓ New best F1: 0.5872
# Epoch 5/120
#   Train Loss: 0.8753, Train F1: 0.5331
#   Val Loss: 0.3475, Val F1: 0.4872
#   LR: 0.001000
#   ✓ New best F1: 0.6344
#   ✓ New best F1: 0.6615
# Epoch 10/120
#   Train Loss: 0.5858, Train F1: 0.5930
#   Val Loss: 0.3585, Val F1: 0.6547
#   LR: 0.001000
#   ✓ New best F1: 0.6717
#   ✓ New best F1: 0.7481
# Epoch 15/120
#   Train Loss: 0.3812, Train F1: 0.6416
#   Val Loss: 0.3684, Val F1: 0.7235
#   LR: 0.001000
# Epoch 20/120
#   Train Loss: 0.2785, Train F1: 0.7285
#   Val Loss: 0.4341, Val F1: 0.6615
#   LR: 0.000500
# Epoch 25/120
#   Train Loss: 0.1979, Train F1: 0.8328
#   Val Loss: 0.4528, Val F1: 0.6530
#   LR: 0.000250
# Epoch 30/120
#   Train Loss: 0.1318, Train F1: 0.8745
#   Val Loss: 0.5447, Val F1: 0.6120
#   LR: 0.000125
#   → Learning rate reduced from 0.000250 to 0.000125
#
# Early stopping triggered after 32 epochs
#
# Training completed. Best Val F1: 0.7481
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.89      0.97      0.93       265
#     Important       0.53      0.20      0.29        41
#
#      accuracy                           0.87       306
#     macro avg       0.71      0.58      0.61       306
#  weighted avg       0.84      0.87      0.84       306
#
#
# ============================================================
# Testing configuration 8/27
# ============================================================
# {'hidden_dims': [832, 416, 208], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 6.8958, Train F1: 0.4122
#   Val Loss: 0.8944, Val F1: 0.6818
#   LR: 0.001000
#   ✓ New best F1: 0.6818
#   ✓ New best F1: 0.7278
# Epoch 5/120
#   Train Loss: 1.4734, Train F1: 0.6785
#   Val Loss: 0.8659, Val F1: 0.7324
#   LR: 0.001000
#   ✓ New best F1: 0.7324
#   ✓ New best F1: 0.7341
# Epoch 10/120
#   Train Loss: 0.8293, Train F1: 0.7632
#   Val Loss: 1.3526, Val F1: 0.5505
#   LR: 0.001000
# Epoch 15/120
#   Train Loss: 0.4025, Train F1: 0.8648
#   Val Loss: 1.4010, Val F1: 0.6299
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.2802, Train F1: 0.8824
#   Val Loss: 1.2327, Val F1: 0.6526
#   LR: 0.000250
# Epoch 25/120
#   Train Loss: 0.2717, Train F1: 0.9138
#   Val Loss: 1.4715, Val F1: 0.6342
#   LR: 0.000125
#
# Early stopping triggered after 26 epochs
#
# Training completed. Best Val F1: 0.7341
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.90      0.97      0.93       265
#     Important       0.58      0.27      0.37        41
#
#      accuracy                           0.88       306
#     macro avg       0.74      0.62      0.65       306
#  weighted avg       0.85      0.88      0.86       306
#
#
# ============================================================
# Testing configuration 9/27
# ============================================================
# {'hidden_dims': [768, 512, 256, 128], 'dropout_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 6.6491, Train F1: 0.3661
#   Val Loss: 1.1212, Val F1: 0.5271
#   LR: 0.001000
#   ✓ New best F1: 0.5271
#   ✓ New best F1: 0.5463
#   ✓ New best F1: 0.5735
#   ✓ New best F1: 0.6342
# Epoch 5/120
#   Train Loss: 1.5361, Train F1: 0.6031
#   Val Loss: 0.6477, Val F1: 0.6141
#   LR: 0.001000
#   ✓ New best F1: 0.6547
# Epoch 10/120
#   Train Loss: 0.8578, Train F1: 0.6984
#   Val Loss: 0.9689, Val F1: 0.5765
#   LR: 0.001000
# Epoch 15/120
#   Train Loss: 0.5939, Train F1: 0.7723
#   Val Loss: 0.9807, Val F1: 0.4632
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.3812, Train F1: 0.8095
#   Val Loss: 0.9729, Val F1: 0.5829
#   LR: 0.000250
#   → Learning rate reduced from 0.000500 to 0.000250
# Epoch 25/120
#   Train Loss: 0.2802, Train F1: 0.8459
#   Val Loss: 1.1108, Val F1: 0.5323
#   LR: 0.000250
#
# Early stopping triggered after 28 epochs
#
# Training completed. Best Val F1: 0.6547
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.88      0.99      0.93       265
#     Important       0.71      0.12      0.21        41
#
#      accuracy                           0.88       306
#     macro avg       0.80      0.56      0.57       306
#  weighted avg       0.86      0.88      0.84       306
#
#
# ============================================================
# Testing configuration 10/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.0008, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 4.0961, Train F1: 0.4891
#   Val Loss: 1.0394, Val F1: 0.6137
#   LR: 0.000800
#   ✓ New best F1: 0.6137
#   ✓ New best F1: 0.6405
#   ✓ New best F1: 0.7146
# Epoch 5/120
#   Train Loss: 1.5400, Train F1: 0.6508
#   Val Loss: 0.8179, Val F1: 0.6926
#   LR: 0.000800
# Epoch 10/120
#   Train Loss: 0.8234, Train F1: 0.7538
#   Val Loss: 1.0526, Val F1: 0.6277
#   LR: 0.000400
# Epoch 15/120
#   Train Loss: 0.5815, Train F1: 0.8026
#   Val Loss: 1.1621, Val F1: 0.6231
#   LR: 0.000200
#   → Learning rate reduced from 0.000400 to 0.000200
# Epoch 20/120
#   Train Loss: 0.5446, Train F1: 0.8229
#   Val Loss: 1.2761, Val F1: 0.6299
#   LR: 0.000200
#
# Early stopping triggered after 23 epochs
#
# Training completed. Best Val F1: 0.7146
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.90      0.94      0.92       265
#     Important       0.43      0.29      0.35        41
#
#      accuracy                           0.85       306
#     macro avg       0.66      0.62      0.63       306
#  weighted avg       0.83      0.85      0.84       306
#
#
# ============================================================
# Testing configuration 11/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.0012, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 2.8779, Train F1: 0.5290
#   Val Loss: 0.6984, Val F1: 0.7102
#   LR: 0.001200
#   ✓ New best F1: 0.7102
#   ✓ New best F1: 0.7168
# Epoch 5/120
#   Train Loss: 1.4828, Train F1: 0.6550
#   Val Loss: 0.9307, Val F1: 0.6926
#   LR: 0.001200
#   ✓ New best F1: 0.7225
# Epoch 10/120
#   Train Loss: 0.7543, Train F1: 0.7639
#   Val Loss: 1.0985, Val F1: 0.6405
#   LR: 0.001200
# Epoch 15/120
#   Train Loss: 0.3247, Train F1: 0.8591
#   Val Loss: 1.2085, Val F1: 0.6574
#   LR: 0.000600
# Epoch 20/120
#   Train Loss: 0.2267, Train F1: 0.8891
#   Val Loss: 1.1752, Val F1: 0.6694
#   LR: 0.000300
# Epoch 25/120
#   Train Loss: 0.1571, Train F1: 0.9300
#   Val Loss: 1.1733, Val F1: 0.6222
#   LR: 0.000150
#   → Learning rate reduced from 0.000300 to 0.000150
#
# Early stopping triggered after 27 epochs
#
# Training completed. Best Val F1: 0.7225
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.90      0.92      0.91       265
#     Important       0.41      0.37      0.38        41
#
#      accuracy                           0.84       306
#     macro avg       0.65      0.64      0.65       306
#  weighted avg       0.84      0.84      0.84       306
#
#
# ============================================================
# Testing configuration 12/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.0015, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 7.4382, Train F1: 0.4234
#   Val Loss: 0.8833, Val F1: 0.6261
#   LR: 0.001500
#   ✓ New best F1: 0.6261
#   ✓ New best F1: 0.6603
# Epoch 5/120
#   Train Loss: 1.5301, Train F1: 0.6619
#   Val Loss: 1.1865, Val F1: 0.7083
#   LR: 0.001500
#   ✓ New best F1: 0.7083
# Epoch 10/120
#   Train Loss: 0.8229, Train F1: 0.7723
#   Val Loss: 1.2391, Val F1: 0.6899
#   LR: 0.001500
# Epoch 15/120
#   Train Loss: 0.4020, Train F1: 0.8473
#   Val Loss: 1.2061, Val F1: 0.6564
#   LR: 0.000750
# Epoch 20/120
#   Train Loss: 0.2353, Train F1: 0.8989
#   Val Loss: 1.3096, Val F1: 0.6471
#   LR: 0.000375
# Epoch 25/120
#   Train Loss: 0.1421, Train F1: 0.9111
#   Val Loss: 1.2950, Val F1: 0.6299
#   LR: 0.000188
#
# Early stopping triggered after 25 epochs
#
# Training completed. Best Val F1: 0.7083
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.89      0.95      0.92       265
#     Important       0.46      0.27      0.34        41
#
#      accuracy                           0.86       306
#     macro avg       0.68      0.61      0.63       306
#  weighted avg       0.84      0.86      0.84       306
#
#
# ============================================================
# Testing configuration 13/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 2e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 2.9706, Train F1: 0.5368
#   Val Loss: 0.7590, Val F1: 0.6294
#   LR: 0.001000
#   ✓ New best F1: 0.6294
#   ✓ New best F1: 0.6980
# Epoch 5/120
#   Train Loss: 1.3650, Train F1: 0.6678
#   Val Loss: 0.7994, Val F1: 0.6500
#   LR: 0.001000
# Epoch 10/120
#   Train Loss: 0.6976, Train F1: 0.7782
#   Val Loss: 1.1030, Val F1: 0.6373
#   LR: 0.000500
# Epoch 15/120
#   Train Loss: 0.5161, Train F1: 0.8218
#   Val Loss: 1.0435, Val F1: 0.6451
#   LR: 0.000250
#   → Learning rate reduced from 0.000500 to 0.000250
# Epoch 20/120
#   Train Loss: 0.3163, Train F1: 0.8734
#   Val Loss: 1.0777, Val F1: 0.6510
#   LR: 0.000250
#
# Early stopping triggered after 23 epochs
#
# Training completed. Best Val F1: 0.6980
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.90      0.95      0.92       265
#     Important       0.46      0.29      0.36        41
#
#      accuracy                           0.86       306
#     macro avg       0.68      0.62      0.64       306
#  weighted avg       0.84      0.86      0.85       306
#
#
# ============================================================
# Testing configuration 14/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 5e-06, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 6.0051, Train F1: 0.4281
#   Val Loss: 0.7853, Val F1: 0.6805
#   LR: 0.001000
#   ✓ New best F1: 0.6805
#   ✓ New best F1: 0.7240
#   ✓ New best F1: 0.7387
# Epoch 5/120
#   Train Loss: 1.5967, Train F1: 0.6463
#   Val Loss: 1.0577, Val F1: 0.7400
#   LR: 0.001000
#   ✓ New best F1: 0.7400
# Epoch 10/120
#   Train Loss: 0.9536, Train F1: 0.7689
#   Val Loss: 1.3155, Val F1: 0.6949
#   LR: 0.001000
# Epoch 15/120
#   Train Loss: 0.5988, Train F1: 0.8274
#   Val Loss: 1.4335, Val F1: 0.6943
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.4022, Train F1: 0.8585
#   Val Loss: 1.3595, Val F1: 0.6967
#   LR: 0.000250
# Epoch 25/120
#   Train Loss: 0.2428, Train F1: 0.9142
#   Val Loss: 1.3402, Val F1: 0.6967
#   LR: 0.000125
#
# Early stopping triggered after 25 epochs
#
# Training completed. Best Val F1: 0.7400
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.91      0.94      0.93       265
#     Important       0.53      0.41      0.47        41
#
#      accuracy                           0.87       306
#     macro avg       0.72      0.68      0.70       306
#  weighted avg       0.86      0.87      0.87       306
#
#
# ============================================================
# Testing configuration 15/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 2e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 2.4100, Train F1: 0.5506
#   Val Loss: 1.2352, Val F1: 0.6431
#   LR: 0.001000
#   ✓ New best F1: 0.6431
#   ✓ New best F1: 0.6872
#   ✓ New best F1: 0.6988
# Epoch 5/120
#   Train Loss: 1.0199, Train F1: 0.7192
#   Val Loss: 1.0474, Val F1: 0.6546
#   LR: 0.001000
# Epoch 10/120
#   Train Loss: 0.5746, Train F1: 0.7877
#   Val Loss: 1.2338, Val F1: 0.6579
#   LR: 0.000500
#   → Learning rate reduced from 0.001000 to 0.000500
#   ✓ New best F1: 0.7024
# Epoch 15/120
#   Train Loss: 0.3436, Train F1: 0.8484
#   Val Loss: 1.1855, Val F1: 0.6464
#   LR: 0.000500
#   ✓ New best F1: 0.7199
# Epoch 20/120
#   Train Loss: 0.1545, Train F1: 0.9129
#   Val Loss: 1.3554, Val F1: 0.6573
#   LR: 0.000500
# Epoch 25/120
#   Train Loss: 0.1133, Train F1: 0.9376
#   Val Loss: 1.3946, Val F1: 0.7012
#   LR: 0.000250
# Epoch 30/120
#   Train Loss: 0.0696, Train F1: 0.9629
#   Val Loss: 1.5754, Val F1: 0.6690
#   LR: 0.000125
#   → Learning rate reduced from 0.000250 to 0.000125
# Epoch 35/120
#   Train Loss: 0.0576, Train F1: 0.9698
#   Val Loss: 1.4513, Val F1: 0.6911
#   LR: 0.000125
#
# Early stopping triggered after 38 epochs
#
# Training completed. Best Val F1: 0.7199
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.91      0.89      0.90       265
#     Important       0.39      0.44      0.41        41
#
#      accuracy                           0.83       306
#     macro avg       0.65      0.67      0.66       306
#  weighted avg       0.84      0.83      0.84       306
#
#
# ============================================================
# Testing configuration 16/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 64, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 3.5380, Train F1: 0.4883
#   Val Loss: 1.1944, Val F1: 0.6151
#   LR: 0.001000
#   ✓ New best F1: 0.6151
#   ✓ New best F1: 0.6618
#   ✓ New best F1: 0.6772
#   ✓ New best F1: 0.7080
# Epoch 5/120
#   Train Loss: 1.1703, Train F1: 0.6895
#   Val Loss: 0.7521, Val F1: 0.6581
#   LR: 0.001000
# Epoch 10/120
#   Train Loss: 0.8363, Train F1: 0.7590
#   Val Loss: 0.9921, Val F1: 0.6734
#   LR: 0.000500
#   → Learning rate reduced from 0.001000 to 0.000500
# Epoch 15/120
#   Train Loss: 0.5167, Train F1: 0.8424
#   Val Loss: 0.9995, Val F1: 0.6549
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.3069, Train F1: 0.8634
#   Val Loss: 1.0321, Val F1: 0.6451
#   LR: 0.000250
#
# Early stopping triggered after 24 epochs
#
# Training completed. Best Val F1: 0.7080
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.89      0.96      0.92       265
#     Important       0.48      0.24      0.32        41
#
#      accuracy                           0.86       306
#     macro avg       0.68      0.60      0.62       306
#  weighted avg       0.84      0.86      0.84       306
#
#
# ============================================================
# Testing configuration 17/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 16, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 6.1166, Train F1: 0.4309
#   Val Loss: 0.9269, Val F1: 0.5587
#   LR: 0.001000
#   ✓ New best F1: 0.5587
#   ✓ New best F1: 0.6043
#   ✓ New best F1: 0.6257
#   ✓ New best F1: 0.6590
# Epoch 5/120
#   Train Loss: 1.6083, Train F1: 0.6585
#   Val Loss: 1.0311, Val F1: 0.5559
#   LR: 0.001000
# Epoch 10/120
#   Train Loss: 0.7893, Train F1: 0.7712
#   Val Loss: 1.2581, Val F1: 0.5644
#   LR: 0.000500
#   → Learning rate reduced from 0.001000 to 0.000500
# Epoch 15/120
#   Train Loss: 0.3598, Train F1: 0.8465
#   Val Loss: 1.2098, Val F1: 0.6104
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.3253, Train F1: 0.8437
#   Val Loss: 1.2065, Val F1: 0.6007
#   LR: 0.000250
#
# Early stopping triggered after 24 epochs
#
# Training completed. Best Val F1: 0.6590
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.89      0.98      0.93       265
#     Important       0.62      0.20      0.30        41
#
#      accuracy                           0.88       306
#     macro avg       0.75      0.59      0.61       306
#  weighted avg       0.85      0.88      0.85       306
#
#
# ============================================================
# Testing configuration 18/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.5, 'learning_rate': 0.0012, 'weight_decay': 1e-05, 'batch_size': 64, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 10.2464, Train F1: 0.3376
#   Val Loss: 2.7158, Val F1: 0.5393
#   LR: 0.001200
#   ✓ New best F1: 0.5393
#   ✓ New best F1: 0.6431
#   ✓ New best F1: 0.6733
# Epoch 5/120
#   Train Loss: 1.5521, Train F1: 0.6450
#   Val Loss: 1.0485, Val F1: 0.6191
#   LR: 0.001200
# Epoch 10/120
#   Train Loss: 1.2099, Train F1: 0.7236
#   Val Loss: 1.2697, Val F1: 0.6659
#   LR: 0.000600
# Epoch 15/120
#   Train Loss: 0.7337, Train F1: 0.8229
#   Val Loss: 1.4775, Val F1: 0.6397
#   LR: 0.000300
#   → Learning rate reduced from 0.000600 to 0.000300
# Epoch 20/120
#   Train Loss: 0.4908, Train F1: 0.8543
#   Val Loss: 1.4951, Val F1: 0.6510
#   LR: 0.000300
#
# Early stopping triggered after 23 epochs
#
# Training completed. Best Val F1: 0.6733
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.89      0.96      0.92       265
#     Important       0.48      0.24      0.32        41
#
#      accuracy                           0.86       306
#     macro avg       0.68      0.60      0.62       306
#  weighted avg       0.84      0.86      0.84       306
#
#
# ============================================================
# Testing configuration 19/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.475, 'learning_rate': 0.0008, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 3.2773, Train F1: 0.4871
#   Val Loss: 0.9280, Val F1: 0.6851
#   LR: 0.000800
#   ✓ New best F1: 0.6851
#   ✓ New best F1: 0.7037
#   ✓ New best F1: 0.7083
# Epoch 5/120
#   Train Loss: 1.1469, Train F1: 0.6690
#   Val Loss: 0.9984, Val F1: 0.6727
#   LR: 0.000800
# Epoch 10/120
#   Train Loss: 0.5786, Train F1: 0.8091
#   Val Loss: 1.3096, Val F1: 0.6695
#   LR: 0.000400
#   → Learning rate reduced from 0.000800 to 0.000400
# Epoch 15/120
#   Train Loss: 0.3641, Train F1: 0.8558
#   Val Loss: 1.3047, Val F1: 0.6474
#   LR: 0.000400
# Epoch 20/120
#   Train Loss: 0.3447, Train F1: 0.8944
#   Val Loss: 1.5160, Val F1: 0.6155
#   LR: 0.000200
#
# Early stopping triggered after 24 epochs
#
# Training completed. Best Val F1: 0.7083
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.91      0.93      0.92       265
#     Important       0.47      0.41      0.44        41
#
#      accuracy                           0.86       306
#     macro avg       0.69      0.67      0.68       306
#  weighted avg       0.85      0.86      0.86       306
#
#
# ============================================================
# Testing configuration 20/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.5, 'learning_rate': 0.0012, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 2.6019, Train F1: 0.5364
#   Val Loss: 0.8142, Val F1: 0.6926
#   LR: 0.001200
#   ✓ New best F1: 0.6926
#   ✓ New best F1: 0.6964
# Epoch 5/120
#   Train Loss: 1.2122, Train F1: 0.6959
#   Val Loss: 1.0850, Val F1: 0.6815
#   LR: 0.001200
# Epoch 10/120
#   Train Loss: 0.6317, Train F1: 0.7795
#   Val Loss: 1.0452, Val F1: 0.5998
#   LR: 0.000600
#   → Learning rate reduced from 0.001200 to 0.000600
# Epoch 15/120
#   Train Loss: 0.3143, Train F1: 0.8719
#   Val Loss: 1.3244, Val F1: 0.5872
#   LR: 0.000600
# Epoch 20/120
#   Train Loss: 0.1559, Train F1: 0.9331
#   Val Loss: 1.1709, Val F1: 0.5955
#   LR: 0.000300
#
# Early stopping triggered after 24 epochs
#
# Training completed. Best Val F1: 0.6964
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.90      0.94      0.92       265
#     Important       0.41      0.29      0.34        41
#
#      accuracy                           0.85       306
#     macro avg       0.65      0.61      0.63       306
#  weighted avg       0.83      0.85      0.84       306
#
#
# ============================================================
# Testing configuration 21/27
# ============================================================
# {'hidden_dims': [768, 384, 192, 96], 'dropout_rate': 0.475, 'learning_rate': 0.001, 'weight_decay': 2e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 2.1424, Train F1: 0.4865
#   Val Loss: 0.4856, Val F1: 0.6212
#   LR: 0.001000
#   ✓ New best F1: 0.6212
#   ✓ New best F1: 0.6462
# Epoch 5/120
#   Train Loss: 1.0777, Train F1: 0.6089
#   Val Loss: 0.5938, Val F1: 0.5862
#   LR: 0.001000
# Epoch 10/120
#   Train Loss: 0.6487, Train F1: 0.6888
#   Val Loss: 0.6472, Val F1: 0.6178
#   LR: 0.000500
#   → Learning rate reduced from 0.001000 to 0.000500
# Epoch 15/120
#   Train Loss: 0.3821, Train F1: 0.7618
#   Val Loss: 0.6229, Val F1: 0.5862
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.2895, Train F1: 0.7921
#   Val Loss: 0.6972, Val F1: 0.5534
#   LR: 0.000250
#
# Early stopping triggered after 24 epochs
#
# Training completed. Best Val F1: 0.6462
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.88      0.99      0.93       265
#     Important       0.62      0.12      0.20        41
#
#      accuracy                           0.87       306
#     macro avg       0.75      0.56      0.57       306
#  weighted avg       0.85      0.87      0.83       306
#
#
# ============================================================
# Testing configuration 22/27
# ============================================================
# {'hidden_dims': [896, 448, 224], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 11.5154, Train F1: 0.3191
#   Val Loss: 1.9899, Val F1: 0.5734
#   LR: 0.001000
#   ✓ New best F1: 0.5734
#   ✓ New best F1: 0.6893
# Epoch 5/120
#   Train Loss: 1.6979, Train F1: 0.6594
#   Val Loss: 1.3643, Val F1: 0.7296
#   LR: 0.001000
#   ✓ New best F1: 0.7296
# Epoch 10/120
#   Train Loss: 0.9677, Train F1: 0.7689
#   Val Loss: 1.9361, Val F1: 0.6080
#   LR: 0.001000
# Epoch 15/120
#   Train Loss: 0.4830, Train F1: 0.8726
#   Val Loss: 1.7165, Val F1: 0.6449
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.3735, Train F1: 0.9034
#   Val Loss: 1.7279, Val F1: 0.6449
#   LR: 0.000250
# Epoch 25/120
#   Train Loss: 0.2615, Train F1: 0.9225
#   Val Loss: 1.7261, Val F1: 0.6644
#   LR: 0.000125
#
# Early stopping triggered after 25 epochs
#
# Training completed. Best Val F1: 0.7296
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.90      0.96      0.93       265
#     Important       0.54      0.32      0.40        41
#
#      accuracy                           0.87       306
#     macro avg       0.72      0.64      0.66       306
#  weighted avg       0.85      0.87      0.86       306
#
#
# ============================================================
# Testing configuration 23/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.0015, 'weight_decay': 1e-05, 'batch_size': 16, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 3.1579, Train F1: 0.4902
#   Val Loss: 0.8185, Val F1: 0.6695
#   LR: 0.001500
#   ✓ New best F1: 0.6695
#   ✓ New best F1: 0.6930
# Epoch 5/120
#   Train Loss: 1.1276, Train F1: 0.7003
#   Val Loss: 1.0087, Val F1: 0.5955
#   LR: 0.001500
#   ✓ New best F1: 0.7037
# Epoch 10/120
#   Train Loss: 0.5453, Train F1: 0.7593
#   Val Loss: 1.0732, Val F1: 0.6631
#   LR: 0.001500
# Epoch 15/120
#   Train Loss: 0.2615, Train F1: 0.8634
#   Val Loss: 0.8975, Val F1: 0.6085
#   LR: 0.000750
# Epoch 20/120
#   Train Loss: 0.1474, Train F1: 0.9034
#   Val Loss: 1.0171, Val F1: 0.6360
#   LR: 0.000375
#   → Learning rate reduced from 0.000750 to 0.000375
# Epoch 25/120
#   Train Loss: 0.0777, Train F1: 0.9483
#   Val Loss: 1.1490, Val F1: 0.6157
#   LR: 0.000375
#
# Early stopping triggered after 28 epochs
#
# Training completed. Best Val F1: 0.7037
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.89      0.94      0.92       265
#     Important       0.42      0.27      0.33        41
#
#      accuracy                           0.85       306
#     macro avg       0.66      0.61      0.62       306
#  weighted avg       0.83      0.85      0.84       306
#
#
# ============================================================
# Testing configuration 24/27
# ============================================================
# {'hidden_dims': [960, 480, 240], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 4.2368, Train F1: 0.4893
#   Val Loss: 1.0297, Val F1: 0.6573
#   LR: 0.001000
#   ✓ New best F1: 0.6573
#   ✓ New best F1: 0.7024
# Epoch 5/120
#   Train Loss: 1.3519, Train F1: 0.7004
#   Val Loss: 1.0731, Val F1: 0.7061
#   LR: 0.001000
#   ✓ New best F1: 0.7061
# Epoch 10/120
#   Train Loss: 0.9164, Train F1: 0.7769
#   Val Loss: 1.2818, Val F1: 0.6500
#   LR: 0.001000
# Epoch 15/120
#   Train Loss: 0.3719, Train F1: 0.8821
#   Val Loss: 1.5901, Val F1: 0.6618
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.2112, Train F1: 0.9171
#   Val Loss: 1.6873, Val F1: 0.6267
#   LR: 0.000250
# Epoch 25/120
#   Train Loss: 0.1908, Train F1: 0.9289
#   Val Loss: 1.6429, Val F1: 0.6768
#   LR: 0.000125
#
# Early stopping triggered after 25 epochs
#
# Training completed. Best Val F1: 0.7061
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.91      0.92      0.92       265
#     Important       0.46      0.41      0.44        41
#
#      accuracy                           0.86       306
#     macro avg       0.69      0.67      0.68       306
#  weighted avg       0.85      0.86      0.85       306
#
#
# ============================================================
# Testing configuration 25/27
# ============================================================
# {'hidden_dims': [768, 576, 384, 192], 'dropout_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 2.6188, Train F1: 0.5156
#   Val Loss: 0.6130, Val F1: 0.6034
#   LR: 0.001000
#   ✓ New best F1: 0.6034
#   ✓ New best F1: 0.6978
#   ✓ New best F1: 0.7184
#   ✓ New best F1: 0.7502
# Epoch 5/120
#   Train Loss: 1.6763, Train F1: 0.6080
#   Val Loss: 0.7309, Val F1: 0.7235
#   LR: 0.001000
# Epoch 10/120
#   Train Loss: 0.8505, Train F1: 0.7325
#   Val Loss: 1.2864, Val F1: 0.5045
#   LR: 0.000500
#   → Learning rate reduced from 0.001000 to 0.000500
# Epoch 15/120
#   Train Loss: 0.5869, Train F1: 0.8064
#   Val Loss: 1.1915, Val F1: 0.5674
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.4275, Train F1: 0.8354
#   Val Loss: 1.3014, Val F1: 0.5615
#   LR: 0.000250
#
# Early stopping triggered after 24 epochs
#
# Training completed. Best Val F1: 0.7502
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.88      0.99      0.93       265
#     Important       0.62      0.12      0.20        41
#
#      accuracy                           0.87       306
#     macro avg       0.75      0.56      0.57       306
#  weighted avg       0.85      0.87      0.83       306
#
#
# ============================================================
# Testing configuration 26/27
# ============================================================
# {'hidden_dims': [704, 384, 192, 96], 'dropout_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Epoch 1/120
#   Train Loss: 2.0033, Train F1: 0.4912
#   Val Loss: 0.4605, Val F1: 0.5253
#   LR: 0.001000
#   ✓ New best F1: 0.5253
#   ✓ New best F1: 0.5972
#   ✓ New best F1: 0.6342
# Epoch 5/120
#   Train Loss: 1.0619, Train F1: 0.6092
#   Val Loss: 0.4527, Val F1: 0.5872
#   LR: 0.001000
#   ✓ New best F1: 0.6385
# Epoch 10/120
#   Train Loss: 0.7498, Train F1: 0.6335
#   Val Loss: 0.5943, Val F1: 0.6257
#   LR: 0.001000
# Epoch 15/120
#   Train Loss: 0.3838, Train F1: 0.7384
#   Val Loss: 0.5269, Val F1: 0.6104
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.2492, Train F1: 0.8039
#   Val Loss: 0.6641, Val F1: 0.5506
#   LR: 0.000250
# Epoch 25/120
#   Train Loss: 0.1665, Train F1: 0.8542
#   Val Loss: 0.6692, Val F1: 0.5534
#   LR: 0.000125
#   → Learning rate reduced from 0.000250 to 0.000125
#
# Early stopping triggered after 27 epochs
#
# Training completed. Best Val F1: 0.6385
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.88      1.00      0.93       265
#     Important       0.80      0.10      0.17        41
#
#      accuracy                           0.88       306
#     macro avg       0.84      0.55      0.55       306
#  weighted avg       0.87      0.88      0.83       306
#
#
# ============================================================
# Testing configuration 27/27
# ============================================================
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 150, 'early_stopping_patience': 25}
# Epoch 1/150
#   Train Loss: 2.2919, Train F1: 0.5229
#   Val Loss: 0.9904, Val F1: 0.7206
#   LR: 0.001000
#   ✓ New best F1: 0.7206
#   ✓ New best F1: 0.7346
#   ✓ New best F1: 0.7525
# Epoch 5/150
#   Train Loss: 1.2181, Train F1: 0.6729
#   Val Loss: 0.8773, Val F1: 0.7516
#   LR: 0.001000
# Epoch 10/150
#   Train Loss: 0.6474, Train F1: 0.7893
#   Val Loss: 1.0149, Val F1: 0.7146
#   LR: 0.000500
# Epoch 15/150
#   Train Loss: 0.3587, Train F1: 0.8647
#   Val Loss: 0.9558, Val F1: 0.7037
#   LR: 0.000250
#   → Learning rate reduced from 0.000500 to 0.000250
# Epoch 20/150
#   Train Loss: 0.2720, Train F1: 0.8901
#   Val Loss: 1.0056, Val F1: 0.6695
#   LR: 0.000250
# Epoch 25/150
#   Train Loss: 0.2945, Train F1: 0.8535
#   Val Loss: 1.0745, Val F1: 0.6811
#   LR: 0.000125
#
# Early stopping triggered after 28 epochs
#
# Training completed. Best Val F1: 0.7525
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.91      0.94      0.92       265
#     Important       0.48      0.39      0.43        41
#
#      accuracy                           0.86       306
#     macro avg       0.70      0.66      0.68       306
#  weighted avg       0.85      0.86      0.86       306
#
#
# ============================================================
# SUMMARY OF ALL CONFIGURATIONS:
# ============================================================
#
# 1. F1: 0.7555
#    Config 5: {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.55, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
#
# 2. F1: 0.7525
#    Config 27: {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 150, 'early_stopping_patience': 25}
#
# 3. F1: 0.7502
#    Config 25: {'hidden_dims': [768, 576, 384, 192], 'dropout_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
#
# 4. F1: 0.7481
#    Config 7: {'hidden_dims': [768, 384, 192, 96, 48], 'dropout_rate': 0.5, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
#
# 5. F1: 0.7400
#    Config 14: {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.525, 'learning_rate': 0.001, 'weight_decay': 5e-06, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
#
# ============================================================
# BEST CONFIGURATION:
# {'hidden_dims': [768, 384, 192], 'dropout_rate': 0.55, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 32, 'num_epochs': 120, 'early_stopping_patience': 20}
# Best F1 Score: 0.7555
# ============================================================
#
# Training final model...
# Epoch 1/120
#   Train Loss: 2.6505, Train F1: 0.5153
#   Val Loss: 0.8160, Val F1: 0.7327
#   LR: 0.001000
#   ✓ New best F1: 0.7327
#   ✓ New best F1: 0.7361
# Epoch 5/120
#   Train Loss: 1.4446, Train F1: 0.7038
#   Val Loss: 0.9004, Val F1: 0.6926
#   LR: 0.001000
# Epoch 10/120
#   Train Loss: 0.8302, Train F1: 0.7759
#   Val Loss: 1.2040, Val F1: 0.6196
#   LR: 0.000500
#   → Learning rate reduced from 0.001000 to 0.000500
# Epoch 15/120
#   Train Loss: 0.5018, Train F1: 0.8154
#   Val Loss: 1.0106, Val F1: 0.6733
#   LR: 0.000500
# Epoch 20/120
#   Train Loss: 0.3698, Train F1: 0.8627
#   Val Loss: 1.0465, Val F1: 0.6581
#   LR: 0.000250
#
# Early stopping triggered after 24 epochs
#
# Training completed. Best Val F1: 0.7361
#
# Final Validation Classification Report:
#                precision    recall  f1-score   support
#
# Not Important       0.89      0.94      0.92       265
#     Important       0.41      0.27      0.32        41
#
#      accuracy                           0.85       306
#     macro avg       0.65      0.60      0.62       306
#  weighted avg       0.83      0.85      0.84       306
#
#
# Making predictions on test set...
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_13036\2626167264.py:675: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('best_model.pth')
# ✓ Submission file created: submission.csv
# Predictions: 0=377, 1=123
